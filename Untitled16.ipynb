# %% [markdown]
# <a href="https://colab.research.google.com/github/mayur07699/MLDS/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("/content/IPLPlayerStat-1.csv")

# %%
df
# Out:
#      Unnamed: 0          player  runs  boundaries  balls_faced  wickets  \
# 0             0  A Ashish Reddy   280          31          196     18.0
# 1             1        A Badoni   161          18          139      2.0
# 2             2      A Chandila     4           0            7     11.0
# 3             3        A Chopra    53           7           75      0.0
# 4             4     A Choudhary    25           2           20      5.0
# ..          ...             ...   ...         ...          ...      ...
# 600         600      Yash Dayal     0           0            1     11.0
# 601         601   Yashpal Singh    47           5           67      0.0
# 602         602     Younis Khan     3           0            7      0.0
# 603         603    Yuvraj Singh  2754         367         2207     36.0
# 604         604          Z Khan   117          13          141    102.0
#
#      balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0          player  runs  boundaries  balls_faced  wickets  \
# 0           0  A Ashish Reddy   280          31          196     18.0
# 1           1        A Badoni   161          18          139      2.0
# 2           2      A Chandila     4           0            7     11.0
# 3           3        A Chopra    53           7           75      0.0
# 4           4     A Choudhary    25           2           20      5.0
#
#    balls_bowled  runs_conceded  matches  batting_avg  batting_strike_rate  \
# 0         270.0          400.0       28        10.00               142.86
# 1          12.0           12.0       11        14.64               115.83
# 2         234.0          245.0       12         0.33                57.14
# 3           0.0            0.0        6         8.83                70.67
# 4         108.0          144.0        5         5.00               125.00
#
#    boundaries_percent  bowling_economy  bowling_avg  bowling_strike_rate  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player', 'runs', 'boundaries', 'balls_faced', 'wickets',
#        'balls_bowled', 'runs_conceded', 'matches', 'batting_avg',
#        'batting_strike_rate', 'boundaries_percent', 'bowling_economy',
#        'bowling_avg', 'bowling_strike_rate', 'catches', 'stumpings'],
#       dtype='object')

# %%
if "Unnamed: 0" in df.columns:
  df = df.drop(columns=["Unnamed: 0"])

# %%
df
# Out:
#              player  runs  boundaries  balls_faced  wickets  balls_bowled  \
# 0    A Ashish Reddy   280          31          196     18.0         270.0
# 1          A Badoni   161          18          139      2.0          12.0
# 2        A Chandila     4           0            7     11.0         234.0
# 3          A Chopra    53           7           75      0.0           0.0
# 4       A Choudhary    25           2           20      5.0         108.0
# ..              ...   ...         ...          ...      ...           ...
# 600      Yash Dayal     0           0            1     11.0         205.0
# 601   Yashpal Singh    47           5           67      0.0           0.0
# 602     Younis Khan     3           0            7      0.0           0.0
# 603    Yuvraj Singh  2754         367         2207     36.0         882.0
# 604          Z Khan   117          13          141    102.0        2276.0
#
#      runs_conceded  matches  batting_avg  batting_strike_rate  \
# ...

# %%
X = df[['balls_faced']]
Y = df[['runs']]
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2, random_state= 42)
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
comparison = pd.DataFrame({
    "balls_faced": X_test["balls_faced"].to_numpy().ravel(),
    "actual_runs": Y_test.to_numpy().ravel(),
    "runs_predicted": np.round(y_predicted.ravel(), 1)
})

comparison.head()
# Out:
#    balls_faced  actual_runs  runs_predicted
# 0          434          522           542.1
# 1           27           40            19.3
# 2           57           76            57.9
# 3           31           21            24.5
# 4          552          663           693.6

# %%
print(type(X_test))
print(X_test.shape)

print(type(Y_test))
print(Y_test.shape)

print(y_predicted.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (121, 1)
# <class 'pandas.core.frame.DataFrame'>
# (121, 1)
# (121, 1)
