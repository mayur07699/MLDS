# %% [markdown]
# <a href="https://colab.research.google.com/github/mayur07699/MLDS/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('IPLPlayerStat-1.csv')

# %%
df
# Out:
#      Unnamed: 0          player  runs  ...  bowling_strike_rate  catches  stumpings
# 0             0  A Ashish Reddy   280  ...                15.00      8.0        0.0
# 1             1        A Badoni   161  ...                 6.00      8.0        0.0
# 2             2      A Chandila     4  ...                21.27      2.0        0.0
# 3             3        A Chopra    53  ...                 0.00      2.0        0.0
# 4             4     A Choudhary    25  ...                21.60      0.0        0.0
# ..          ...             ...   ...  ...                  ...      ...        ...
# 600         600      Yash Dayal     0  ...                18.64      1.0        0.0
# 601         601   Yashpal Singh    47  ...                 0.00      3.0        0.0
# 602         602     Younis Khan     3  ...                 0.00      1.0        0.0
# 603         603    Yuvraj Singh  2754  ...                24.50     29.0        0.0
# ...

# %%
df.shape
# Out:
# (605, 17)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'player', 'runs', 'boundaries', 'balls_faced', 'wickets',
#        'balls_bowled', 'runs_conceded', 'matches', 'batting_avg',
#        'batting_strike_rate', 'boundaries_percent', 'bowling_economy',
#        'bowling_avg', 'bowling_strike_rate', 'catches', 'stumpings'],
#       dtype='object')

# %%
df
# Out:
#      Unnamed: 0          player  runs  ...  bowling_strike_rate  catches  stumpings
# 0             0  A Ashish Reddy   280  ...                15.00      8.0        0.0
# 1             1        A Badoni   161  ...                 6.00      8.0        0.0
# 2             2      A Chandila     4  ...                21.27      2.0        0.0
# 3             3        A Chopra    53  ...                 0.00      2.0        0.0
# 4             4     A Choudhary    25  ...                21.60      0.0        0.0
# ..          ...             ...   ...  ...                  ...      ...        ...
# 600         600      Yash Dayal     0  ...                18.64      1.0        0.0
# 601         601   Yashpal Singh    47  ...                 0.00      3.0        0.0
# 602         602     Younis Khan     3  ...                 0.00      1.0        0.0
# 603         603    Yuvraj Singh  2754  ...                24.50     29.0        0.0
# ...

# %%
if 'Unnamed: 0' in df.columns:
  df = df.drop(columns=('Unnamed: 0'))

# %%
df
# Out:
#              player  runs  boundaries  ...  bowling_strike_rate  catches  stumpings
# 0    A Ashish Reddy   280          31  ...                15.00      8.0        0.0
# 1          A Badoni   161          18  ...                 6.00      8.0        0.0
# 2        A Chandila     4           0  ...                21.27      2.0        0.0
# 3          A Chopra    53           7  ...                 0.00      2.0        0.0
# 4       A Choudhary    25           2  ...                21.60      0.0        0.0
# ..              ...   ...         ...  ...                  ...      ...        ...
# 600      Yash Dayal     0           0  ...                18.64      1.0        0.0
# 601   Yashpal Singh    47           5  ...                 0.00      3.0        0.0
# 602     Younis Khan     3           0  ...                 0.00      1.0        0.0
# 603    Yuvraj Singh  2754         367  ...                24.50     29.0        0.0
# ...

# %%
features = ['balls_faced','boundaries','balls_bowled',"stumpings",'batting_strike_rate']
X_multi = df[features]
Y_multi = df['runs']
X_multi_train, X_multi_test, Y_multi_train, Y_multi_test = train_test_split(X_multi, Y_multi, test_size=0.2, random_state=42)
model_multi = LinearRegression()
model.fit(X_multi_train, Y_multi_train)
Y_multi_pred = model.predict(X_multi_test)

# %%
comparsion = pd.DataFrame({"actual":Y_multi_test,"predicted":Y_multi_pred})
comparsion
# Out:
#      actual   predicted
# 412     522  513.341694
# 289      40   41.647345
# 76       76   75.016084
# 78       21   19.287950
# 182     663  649.411911
# ..      ...         ...
# 268    1001  979.249559
# 249       0  -15.299108
# 364      26   16.599897
# 451      31   31.081983
# 464     180  192.257582
#
# [121 rows x 2 columns]
