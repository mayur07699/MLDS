# %% [markdown]
# <a href="https://colab.research.google.com/github/mayur07699/MLDS/blob/main/labelencoding17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/class_ipl_22-26_dataset.csv')

# %%
df
# Out:
#            date  season            city  \
# 0    26-03-2022    2022          Mumbai
# 1    27-03-2022    2022          Mumbai
# 2    27-03-2022    2022          Mumbai
# 3    28-03-2022    2022          Mumbai
# 4    29-03-2022    2022            Pune
# ..          ...     ...             ...
# 362  24-05-2026    2026         Kolkata
# 363  26-05-2026    2026      Dharamsala
# 364  27-05-2026    2026  New Chandigarh
# 365  29-05-2026    2026  New Chandigarh
# 366  31-05-2026    2026       Ahmedabad
#
#                                                  venue  \
# 0                             Wankhede Stadium, Mumbai
# 1                            Brabourne Stadium, Mumbai
# 2                   Dr DY Patil Sports Academy, Mumbai
# 3                             Wankhede Stadium, Mumbai
# 4        Maharashtra Cricket Association Stadium, Pune
# ..                                                 ...
# 362                              Eden Gardens, Kolkata
# ...

# %%
df.isnull().sum()
# Out:
# date               0
# season             0
# city               0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# team1_runs         0
# team1_wickets      0
# team2_runs         0
# team2_wickets      0
# winner             7
# result_type        0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    5
# match_referee      0
# umpire1            0
# umpire2            0
# tv_umpire          0
# reserve_umpire     0
# overs_limit        0
# team1_players      0
# team2_players      0
# dtype: int64

# %%
df.head(10)
# Out:
#          date  season    city                                          venue  \
# 0  26-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 1  27-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 2  27-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 3  28-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 4  29-03-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
# 5  30-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 6  31-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 7  01-04-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 8  02-04-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
# 9  02-04-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
#
#                          team1                        team2  \
# ...

# %%
lb = LabelEncoder()
df['Winner_encoded']= lb.fit_transform(df['winner'])

# %%
mapping = pd.DataFrame({
    'Winner': lb.classes_,
    'Encoded_value':range(len(lb.classes_))
})
mapping
# Out:
#                          Winner  Encoded_value
# 0           Chennai Super Kings              0
# 1                Delhi Capitals              1
# 2                Gujarat Titans              2
# 3         Kolkata Knight Riders              3
# 4          Lucknow Super Giants              4
# 5                Mumbai Indians              5
# 6                  Punjab Kings              6
# 7              Rajasthan Royals              7
# 8   Royal Challengers Bangalore              8
# 9   Royal Challengers Bengaluru              9
# 10          Sunrisers Hyderabad             10
# 11                          NaN             11
