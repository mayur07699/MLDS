# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('class_ipl_22-26_dataset_with_nulls.csv')

# %%
df.head()
# Out:
#          date  season    city                                          venue  \
# 0  26-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 1  27-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 2  27-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 3  28-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 4  29-03-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
#
#                          team1                  team2            toss_winner  \
# 0          Chennai Super Kings  Kolkata Knight Riders  Kolkata Knight Riders
# 1               Mumbai Indians         Delhi Capitals         Delhi Capitals
# 2  Royal Challengers Bangalore           Punjab Kings           Punjab Kings
# 3         Lucknow Super Giants         Gujarat Titans         Gujarat Titans
# 4             Rajasthan Royals    Sunrisers Hyderabad    Sunrisers Hyderabad
#
# ...

# %%
df.shape
# Out:
# (367, 25)

# %%
df.isnull().sum()
# Out:
# date                0
# season              0
# city                0
# venue               0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# team1_runs          0
# team1_wickets      12
# team2_runs          0
# team2_wickets       0
# winner              7
# result_type         0
# win_by_runs         0
# win_by_wickets      0
# player_of_match     5
# match_referee       0
# umpire1             0
# umpire2             0
# tv_umpire           0
# reserve_umpire      0
# overs_limit         0
# team1_players       0
# team2_players       0
# dtype: int64

# %%
df.isnull()
# Out:
#       date  season   city  venue  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 362  False   False  False  False  False  False        False          False
# 363  False   False  False  False  False  False        False          False
# 364  False   False  False  False  False  False        False          False
# 365  False   False  False  False  False  False        False          False
# 366  False   False  False  False  False  False        False          False
#
# ...

# %%
mean_df = df.copy()

# %%
mean_val = mean_df['team1_runs'].mean()
print(mean_val)
# Out:
# 185.0708446866485

# %%
mean_df['team1_runs']=mean_df['team1_runs'].fillna(mean_val)
mean_df['team1_runs'].isnull().sum()
# Out:
# np.int64(0)

# %%
team_1null = df['team1_wickets'].isnull()

abc = df['team1_wickets'].mean()

# %%
df['team1_wickets']=df['team1_wickets'].fillna(abc)

# %%
print(mean)

# %%
print(team_1null)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 362     True
# 363    False
# 364    False
# 365    False
# 366    False
# Name: team1_wickets, Length: 367, dtype: bool

# %%
mean_df.isnull()
# Out:
#       date  season   city  venue  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 362  False   False  False  False  False  False        False          False
# 363  False   False  False  False  False  False        False          False
# 364  False   False  False  False  False  False        False          False
# 365  False   False  False  False  False  False        False          False
# 366  False   False  False  False  False  False        False          False
#
# ...

# %%
df.isnull().sum()
# Out:
# date               0
# season             0
# city               0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# team1_runs         0
# team1_wickets      0
# team2_runs         0
# team2_wickets      0
# winner             7
# result_type        0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    5
# match_referee      0
# umpire1            0
# umpire2            0
# tv_umpire          0
# reserve_umpire     0
# overs_limit        0
# team1_players      0
# team2_players      0
# dtype: int64

# %%
 median_df = df.copy()

# %%
median_df.columns
# Out:
# Index(['date', 'season', 'city', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'team1_runs', 'team1_wickets', 'team2_runs',
#        'team2_wickets', 'winner', 'result_type', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'match_referee', 'umpire1',
#        'umpire2', 'tv_umpire', 'reserve_umpire', 'overs_limit',
#        'team1_players', 'team2_players'],
#       dtype='object')

# %%
median_df.head()
# Out:
#          date  season    city                                          venue  \
# 0  26-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 1  27-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 2  27-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 3  28-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 4  29-03-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
#
#                          team1                  team2            toss_winner  \
# 0          Chennai Super Kings  Kolkata Knight Riders  Kolkata Knight Riders
# 1               Mumbai Indians         Delhi Capitals         Delhi Capitals
# 2  Royal Challengers Bangalore           Punjab Kings           Punjab Kings
# 3         Lucknow Super Giants         Gujarat Titans         Gujarat Titans
# 4             Rajasthan Royals    Sunrisers Hyderabad    Sunrisers Hyderabad
#
# ...

# %%
median_df.isnull().sum()
# Out:
# date               0
# season             0
# city               0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# team1_runs         0
# team1_wickets      0
# team2_runs         0
# team2_wickets      0
# winner             7
# result_type        0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    5
# match_referee      0
# umpire1            0
# umpire2            0
# tv_umpire          0
# reserve_umpire     0
# overs_limit        0
# team1_players      0
# team2_players      0
# dtype: int64

# %%
num_columns = median_df.select_dtypes(include='number').columns
print(num_columns)
# Out:
# Index(['season', 'team1_runs', 'team1_wickets', 'team2_runs', 'team2_wickets',
#        'win_by_runs', 'win_by_wickets', 'overs_limit'],
#       dtype='object')

# %%
median_df[num_columns].isnull().sum()
# Out:
# season            0
# team1_runs        0
# team1_wickets     0
# team2_runs        0
# team2_wickets     0
# win_by_runs       0
# win_by_wickets    0
# overs_limit       0
# dtype: int64

# %%
median_df[num_columns] = median_df[num_columns].isnull().median()
# Out:
# /tmp/ipykernel_461/1050389572.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   median_df[num_columns] = median_df[num_columns].isnull().median()

# %%
median_df[num_columns].isnull().sum()
# Out:
# season            0
# team1_runs        0
# team1_wickets     0
# team2_runs        0
# team2_wickets     0
# win_by_runs       0
# win_by_wickets    0
# overs_limit       0
# dtype: int64

# %%
mode_df = df.copy()

# %%
mode_df.head()
# Out:
#          date  season    city                                          venue  \
# 0  26-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 1  27-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 2  27-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 3  28-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 4  29-03-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
#
#                          team1                  team2            toss_winner  \
# 0          Chennai Super Kings  Kolkata Knight Riders  Kolkata Knight Riders
# 1               Mumbai Indians         Delhi Capitals         Delhi Capitals
# 2  Royal Challengers Bangalore           Punjab Kings           Punjab Kings
# 3         Lucknow Super Giants         Gujarat Titans         Gujarat Titans
# 4             Rajasthan Royals    Sunrisers Hyderabad    Sunrisers Hyderabad
#
# ...

# %%
num1 = mode_df.select_dtypes(include='number').columns
print(num1)
# Out:
# Index(['season', 'team1_runs', 'team1_wickets', 'team2_runs', 'team2_wickets',
#        'win_by_runs', 'win_by_wickets', 'overs_limit'],
#       dtype='object')

# %%
mode_df['season'] = mode_df['season'].isnull().mode()

# %%
mode1 = df['season'].mode()
print(mode1)
# Out:
# 0    2022
# 1    2023
# 2    2025
# 3    2026
# Name: season, dtype: int64

# %%
mode_df.isnull().sum()
# Out:
# date                 0
# season             366
# city                 0
# venue                0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# team1_runs           0
# team1_wickets        0
# team2_runs           0
# team2_wickets        0
# winner               7
# result_type          0
# win_by_runs          0
# win_by_wickets       0
# player_of_match      5
# match_referee        0
# umpire1              0
# umpire2              0
# tv_umpire            0
# reserve_umpire       0
# overs_limit          0
# team1_players        0
# team2_players        0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#          date  season    city                                          venue  \
# 0  26-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 1  27-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 2  27-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 3  28-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 4  29-03-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
#
#                          team1                  team2            toss_winner  \
# 0          Chennai Super Kings  Kolkata Knight Riders  Kolkata Knight Riders
# 1               Mumbai Indians         Delhi Capitals         Delhi Capitals
# 2  Royal Challengers Bangalore           Punjab Kings           Punjab Kings
# 3         Lucknow Super Giants         Gujarat Titans         Gujarat Titans
# 4             Rajasthan Royals    Sunrisers Hyderabad    Sunrisers Hyderabad
#
# ...

# %%
df1.isnull().sum()
# Out:
# date               0
# season             0
# city               0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# team1_runs         0
# team1_wickets      0
# team2_runs         0
# team2_wickets      0
# winner             7
# result_type        0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    5
# match_referee      0
# umpire1            0
# umpire2            0
# tv_umpire          0
# reserve_umpire     0
# overs_limit        0
# team1_players      0
# team2_players      0
# dtype: int64

# %%
impute1 = SimpleImputer(strategy='mean')
impute2 = SimpleImputer(strategy='median')
impute3 = SimpleImputer(strategy='most_frequent')

# %%
df1['team1_runs'] = impute1.fit_transform(df1[['team1_runs']])

# %%
df1['team1_wickets']= impute2.fit_transform(df1[['team1_wickets']])

# %%
print(type(df1[['team1_wickets']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
num1 = df1.select_dtypes(include='number')
print(num1)
# Out:
#      season  team1_runs  team1_wickets  team2_runs  team2_wickets  \
# 0      2022       131.0       5.000000         133              4
# 1      2022       177.0       6.242254         179              6
# 2      2022       205.0       2.000000         208              5
# 3      2022       158.0       6.000000         161              5
# 4      2022       210.0       6.000000         149              7
# ..      ...         ...            ...         ...            ...
# 362    2026       203.0       6.242254         163             10
# 363    2026       254.0       5.000000         162             10
# 364    2026       243.0       8.000000         196             10
# 365    2026       214.0       6.000000         219              3
# 366    2026       155.0       8.000000         161              5
#
#      win_by_runs  win_by_wickets  overs_limit
# 0              0               6           20
# 1              0               4           20
# ...
