# %%
import pandas as pd

# %%
df = pd.read_csv('class_ipl_22-26_dataset.csv')

# %%
df.head()
# Out:
#          date  season    city                                          venue  \
# 0  26-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 1  27-03-2022    2022  Mumbai                      Brabourne Stadium, Mumbai
# 2  27-03-2022    2022  Mumbai             Dr DY Patil Sports Academy, Mumbai
# 3  28-03-2022    2022  Mumbai                       Wankhede Stadium, Mumbai
# 4  29-03-2022    2022    Pune  Maharashtra Cricket Association Stadium, Pune
#
#                          team1                  team2            toss_winner  \
# 0          Chennai Super Kings  Kolkata Knight Riders  Kolkata Knight Riders
# 1               Mumbai Indians         Delhi Capitals         Delhi Capitals
# 2  Royal Challengers Bangalore           Punjab Kings           Punjab Kings
# 3         Lucknow Super Giants         Gujarat Titans         Gujarat Titans
# 4             Rajasthan Royals    Sunrisers Hyderabad    Sunrisers Hyderabad
#
# ...

# %%
num_col = df.select_dtypes(include='number').columns

# %%
num_col
# Out:
# Index(['season', 'team1_runs', 'team1_wickets', 'team2_runs', 'team2_wickets',
#        'win_by_runs', 'win_by_wickets', 'overs_limit'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['date', 'season', 'city', 'venue', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'team1_runs', 'team1_wickets', 'team2_runs',
#        'team2_wickets', 'winner', 'result_type', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'match_referee', 'umpire1',
#        'umpire2', 'tv_umpire', 'reserve_umpire', 'overs_limit',
#        'team1_players', 'team2_players'],
#       dtype='object')

# %%
mean_value = df[num_col].mean()
print(mean_value)
# Out:
# season            2024.000000
# team1_runs         185.070845
# team1_wickets        6.242507
# team2_runs         169.250681
# team2_wickets        5.926431
# win_by_runs         15.343324
# win_by_wickets       3.049046
# overs_limit         20.000000
# dtype: float64

# %%
from numpy import median
median_value = df[num_col].median()
print(median_value)
# Out:
# season            2024.0
# team1_runs         187.0
# team1_wickets        6.0
# team2_runs         171.0
# team2_wickets        6.0
# win_by_runs          0.0
# win_by_wickets       2.0
# overs_limit         20.0
# dtype: float64

# %%
mode_value = df[num_col].mode()
print(mode_value)
# Out:
#    season  team1_runs  team1_wickets  team2_runs  team2_wickets  win_by_runs  \
# 0    2022       159.0            6.0       161.0           10.0          0.0
# 1    2023       162.0            NaN         NaN            NaN          NaN
# 2    2025         NaN            NaN         NaN            NaN          NaN
# 3    2026         NaN            NaN         NaN            NaN          NaN
#
#    win_by_wickets  overs_limit
# 0             0.0         20.0
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN

# %%
mode1_value = df['team1_runs'].mode()
print(mode1_value)
# Out:
# 0    159
# 1    162
# Name: team1_runs, dtype: int64

# %%
df['team1_runs'].value_counts()
# Out:
# team1_runs
# 162    8
# 159    8
# 155    7
# 210    7
# 214    7
#       ..
# 242    1
# 75     1
# 225    1
# 247    1
# 255    1
# Name: count, Length: 137, dtype: int64

# %%
df['team1_runs'].unique()
# Out:
# array([131, 177, 205, 158, 210, 128, 137, 171, 193, 180, 169, 161, 149,
#        189, 151, 154, 165, 215, 162, 216, 198, 192, 175, 199, 217, 181,
#        115, 155, 222,  68, 156, 168, 187, 144, 195, 146, 153, 170, 202,
#        152, 143, 173, 207, 176, 208, 160,  97, 209, 133, 178, 159, 150,
#        157, 188, 130, 191, 203, 197, 204, 121, 212, 172, 228, 174, 185,
#        226, 127, 134, 135, 214, 235, 200, 257, 179, 126, 125, 118, 139,
#        227, 167, 218, 182, 213, 186, 223, 233, 206, 277, 272, 183, 163,
#        234, 196, 147, 287,  89, 266, 142, 224, 261, 201, 221, 241, 231,
#        141, 113, 286, 243, 190, 116, 219, 238, 103, 245, 166, 111,  95,
#        236, 122, 278, 230, 184, 101, 220, 250,  25, 240, 164, 194, 254,
#        242, 264,  75, 225, 229, 247, 255])

# %%
std_dev = df[num_col].std()

# %%
print(std_dev)
# Out:
# season             1.421921
# team1_runs        36.516265
# team1_wickets      2.173749
# team2_runs        38.827661
# team2_wickets      2.740614
# win_by_runs       24.782703
# win_by_wickets     3.243791
# overs_limit        0.000000
# dtype: float64

# %%
df.describe()
# Out:
#             season  team1_runs  team1_wickets  team2_runs  team2_wickets  \
# count   367.000000  367.000000     367.000000  367.000000     367.000000
# mean   2024.000000  185.070845       6.242507  169.250681       5.926431
# std       1.421921   36.516265       2.173749   38.827661       2.740614
# min    2022.000000   25.000000       0.000000    0.000000       0.000000
# 25%    2023.000000  161.500000       5.000000  150.500000       4.000000
# 50%    2024.000000  187.000000       6.000000  171.000000       6.000000
# 75%    2025.000000  209.000000       8.000000  196.000000       8.000000
# max    2026.000000  287.000000      10.000000  265.000000      10.000000
#
#        win_by_runs  win_by_wickets  overs_limit
# count   367.000000      367.000000        367.0
# mean     15.343324        3.049046         20.0
# std      24.782703        3.243791          0.0
# min       0.000000        0.000000         20.0
# 25%       0.000000        0.000000         20.0
# ...
